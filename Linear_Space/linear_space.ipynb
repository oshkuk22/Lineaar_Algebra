# %% [markdown]
# __1.__ Исследовать на линейную зависимость:
# $$f_{1}(x)=e^{x}, f_{2}(x)=1, f_{3}(x)=x+1, f_{4}(x)=x-e^{x}.$$

# %% [markdown]
# __Решение:__
# $$ x-e^{x} = x + 1 - 1 - e^{x} \Rightarrow f_{4}(x) = f_{3}(x) - f_{2}(x) - f_{1}(x)$$

# %% [markdown]
# __2.__ Исследовать на линейную зависимость:
# $$f_{1}(x)=2, f_{2}(x)=x, f_{3}(x)=x^{2}, f_{4}(x)=(x+1)^{2}.$$

# %% [markdown]
# __Решение:__
# $$ f_{4}(x) = {(x + 1)}^2 = x^2 + 2x + 1 = x^2 + 2  \cdot  x + 0,5 \cdot 2 \Rightarrow f_{4}(x) = f_{3}(x) + 2 \cdot f_{2}(x) + 0.5 \cdot f_{1}(x)$$

# %% [markdown]
# __3.__ Найти координаты вектора $x = (2, 3, 5)\in \mathbb{R}^{3}$ в базисе $b_{1}=(0, 0, 10)$, $b_{2}=(2, 0, 0)$, $b_{3}=(0, 1, 0)$.

# %% [markdown]
# __Решение:__
#  $$x = (2, 3, 5) = (2, 0, 0) + (0, 3, 0) + (0, 0, 5) = b_{2} + 3 \cdot b_{3} + \frac{1}{2} \cdot b_{1}$$
#  $$ (\frac{1}{2}, 1, 3) $$

# %% [markdown]
# __4.__ Найти координаты вектора $3x^{2}-2x+2\in\mathbb{R}^{3}[x]$:
#
#    а) в базисе $1$, $x$, $x^{2}$;
#
#    б) в базисе $x^{2}$, $x-1$, $1$.

# %% [markdown]
# __Решение:__
#
# a) $(2, -2, 3)$
#
# б) $3x^{2}-2x+2 = 3x^{2}-2(x -1) \Rightarrow (3, -2, 0)$

# %% [markdown]
# __5.__ Установить, является ли линейным подпространством:
#
# а) совокупность всех векторов трехмерного пространства, у которых по крайней мере одна из первых двух координат равна нулю;
#
# б) все векторы, являющиеся линейными комбинациями данных векторов  {𝑢1,𝑢2,…,𝑢𝑛} .

# %% [markdown]
# __Решение:__
#
# a) $(0, a, b) + (c, 0, d) = (c, a, b+d)$
# __не является__
#
# б) __является__, так как какие не возьмем коэффициенты линейной регресии, а также при умнжении на число мы не выйдем за рамки пространства

# %% [markdown]
# __1.__ Найти скалярное произведение векторов $x, y \in \mathbb{R}$:<br>
# а) $x=(0,-3, 6),~y=(-4, 7, 9);$<br>
# б) $x=(7, -4, 0, 1),~y=(-3, 1, 11, 2).$

# %% [markdown]
# __Решение:__
#
# a) $(x=(0,-3, 6),~y=(-4, 7, 9)$
#
# $x \cdot y = 0 \cdot -4 + (-3) \cdot 7 + 6 \cdot 9 = 33$

# %% [markdown]
# б) $x=(7, -4, 0, 1),~y=(-3, 1, 11, 2)$
#
# $x \cdot y = 7 \cdot (-3) + (-4) \cdot 1 + 0 \cdot 11 +  1 \cdot 2= -23$

# %% [markdown]
# __2.__ Найти нормы векторов $(4, 2, 4)$ и $(12, 3, 4)$ и угол между ними.

# %% [markdown]
# ### __Решение:__
#
# Евклидова норма: $\sqrt{4^2 + 2^2 + 4^2} = 6$
#
# Манэеттэновская норма: $ |4| + |2| + |4| = 10$
#
# Евклидова норма: $\sqrt{12^2 + 3^2 + 4^2} = 13$
#
# Манэеттэновская норма: $ |12| + |3| + |4| = 19$
#
# Угол между векторами: $\cos \alpha = \frac{4 \cdot 12 + 2 \cdot 3 + 4 \cdot 4}{6 \cdot 13} = 0.8974 \Rightarrow \alpha = 0.4569$

# %% [markdown]
# __3.__ Будет ли линейное пространство евклидовым, если за скалярное произведение принять:<br>
# а) произведение длин векторов;<br>
# б) утроенное обычное скалярное произведение векторов?<br>

# %% [markdown]
# __Решение:__
#
# a) Пусть $(x=(0,4), y=(2, 0), z=(6,0)$
#
# $|x+y||z| = |x||z| + |y||z|$
#
# $\sqrt{20} \cdot 6 \neq 4 \cdot 6 + 2 \cdot 6 = 36 \Rightarrow$ __не является__
#
# a) __является__ так как умнжение на скаляр ничего не изменит

# %% [markdown]
# __4.__ Какие из нижеперечисленных векторов образуют ортонормированный базис в линейном пространстве $\mathbb{R}^{3}$:<br>
# а) $(1,0,0),(0,0,1);$ <br>
# б) $(1/\sqrt{2},-1/\sqrt{2},0),(1/\sqrt{2},1/\sqrt{2},0), (0,0,1);$<br>
# в) $(1/2, -1/2, 0), (0, 1/2, 1/2), (0,0,1);$<br>
# г) $(1,0,0),(0,1,0),(0,0,1)?$

# %% [markdown]
# __Решение:__
#
# a) не образуют так как всего 2 вектора, а прстранство $\mathbb{R}^{3}$
#
# б) образуют так как попарные скалярные произведения равны нулю
#
# б) не образуют так как не все попарные скалярные произведения равны нулю
#
# г) образуют так как попарные скалярные произведения равны нулю
